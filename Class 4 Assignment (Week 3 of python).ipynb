# %% [markdown]
# # Assignment 1
#
# Your first assignment is to write code to get input from user and store in dictionary and then store that dictionary in list.
# ### Here is the required input:
#
# [
#     {"name" : "Hamza Ali",<br>
#      "age"  : 25,<br>
#      "work" : "A.I",<br>
#      "skills" : ["python", "tensorflow", "cloud"],<br>
#      "degree" : {"title" : "BS", "major" : "computer Science", "completionDate" : "Jun 2019"},<br>
#      "salary" : 259999<br>
#      },<br>
#      {"name" : "Farooq Aziz",<br>
#      "age"  : 27,<br>
#      "work" : "Cloud Native",<br>
#      "skills" : ["ubuntu", "docker", "kubernetes"],<br>
#      "degree" : {"title" : "MS", "major" : "Software engineer", "completionDate" : "May 2018"},<br>
#      "salary" : 200000<br>
#      },<br>
#      {"name" : "Abu Bakr",<br>
#      "age"  : 30,<br>
#      "work" : "Blockchain",<br>
#      "skills" : ["python", "Cryptography", "Ethereum"],<br>
#      "degree" : {"title" : "BS", "major" : "computer Science", "completionDate" : "May 2019"},<br>
#      "salary" : 300000<br>
#      }
# ]
#
# ### Solution

# %%
liststore = []
quit = "notquit"
while (quit != "quit"):
    dic = {}
    dic["name"] = input("Please Enter the Name = ")
    dic["age"] = int(input("Please Enter the Age = "))
    dic["work"] = input("Please Enter the Work or = ")
    skills = [] 
    while (quit != "quit"):
        skills.append(input("Please Enter the one Skill = "))
        quit = input("type 'quit' to stop entering more Skills or press enter to add more skills ")
    dic["skills"] = skills
    dic["degree"] = {}
    dic["degree"]["title"] = input("Please Enter the Degree Title = ")
    dic["degree"]["major"] = input("Please Enter the Your Majors = ")
    dic["degree"]["completeDAte"] = input("Please Enter the Degree Complete Date = ")
    dic["salary"] = int(input("Please Enter the Salary = "))
    liststore.append(dic)
    quit = input("type 'quit' to stop entering more data or press enter to add other person data ")
print("Sucessfull exit below is your entered data")
print(liststore)
# Out:
# Please Enter the Name = Humayl
# Please Enter the Age = 21
# Please Enter the Work or = Devops Internee
# Please Enter the one Skill = CI/CD
# type 'quit' to stop entering more Skills or press enter to add more skills
# Please Enter the one Skill = Docker
# type 'quit' to stop entering more Skills or press enter to add more skills
# Please Enter the one Skill = Python
# type 'quit' to stop entering more Skills or press enter to add more skills quit
# Please Enter the Degree Title = Bachelors of Electrical Engineering
# Please Enter the Your Majors = Computer Systems
# Please Enter the Degree Complete Date = 2018
# Please Enter the Salary = 18000
# type 'quit' to stop entering more data or press enter to add other person data quit
# Sucessfull exit below is your entered data
# ...

# %% [markdown]
# # Assignment 2
#
# ### 2.1 Take input from user and print table in that range. Suppose user input 5 and 10. Then print table of 5,6,7,8,9,10
#
# ### And ouput should be as follows:
#
# 1 x 5 = 5<br>
# 2 x 5 = 10<br>
# 3 x 5 = 15<br>
# 4 x 5 = 20<br>
# 5 x 5 = 25<br>
# 6 x 5 = 30<br>
# 7 x 5 = 35<br>
# 8 x 5 = 40<br>
# 9 x 5 = 45<br>
# 10 x 5 = 50<br>
#
# 1 x 6 = 6<br>
# 2 x 6 = 12<br>
# 3 x 6 = 18<br>
# 4 x 6 = 24<br>
# 5 x 6 = 30<br>
# 6 x 6 = 36<br>
# 7 x 6 = 42<br>
# 8 x 6 = 48<br>
# 9 x 6 = 54<br>
# 10 x 6 = 60<br>
#
# 1 x 7 = 7<br>
# 2 x 7 = 14<br>
# 3 x 7 = 21<br>
# 4 x 7 = 28<br>
# 5 x 7 = 35<br>
# 6 x 7 = 42<br>
# 7 x 7 = 49<br>
# 8 x 7 = 56<br>
# 9 x 7 = 63<br>
# 10 x 7 = 70<br>
#
# 1 x 8 = 8<br>
# 2 x 8 = 16<br>
# 3 x 8 = 24<br>
# 4 x 8 = 32<br>
# 5 x 8 = 40<br>
# 6 x 8 = 48<br>
# 7 x 8 = 56<br>
# 8 x 8 = 64<br>
# 9 x 8 = 72<br>
# 10 x 8 = 80<br>
#
# 1 x 9 = 9<br>
# 2 x 9 = 18<br>
# 3 x 9 = 27<br>
# 4 x 9 = 36<br>
# 5 x 9 = 45<br>
# 6 x 9 = 54<br>
# 7 x 9 = 63<br>
# 8 x 9 = 72<br>
# 9 x 9 = 81<br>
# 10 x 9 = 90<br>
#
# 1 x 10 = 10<br>
# 2 x 10 = 20<br>
# 3 x 10 = 30<br>
# 4 x 10 = 40<br>
# 5 x 10 = 50<br>
# 6 x 10 = 60<br>
# 7 x 10 = 70<br>
# 8 x 10 = 80<br>
# 9 x 10 = 90<br>
# 10 x 10 = 100<br>
#
# ## Solution

# %%
start = int(input("Please enter start point "))
end = int(input("Please enter end point "))

for userrange in range(start,end+1):
    for tablerange in range(1,11):
        print("{} x {} = {}".format(tablerange, userrange, tablerange*userrange))
    print(" ")
# Out:
# Please enter start point 1
# Please enter end point 2
# 1 x 1 = 1
# 2 x 1 = 2
# 3 x 1 = 3
# 4 x 1 = 4
# 5 x 1 = 5
# 6 x 1 = 6
# 7 x 1 = 7
# 8 x 1 = 8
# 9 x 1 = 9
# 10 x 1 = 10
#
# 1 x 2 = 2
# 2 x 2 = 4
# 3 x 2 = 6
# 4 x 2 = 8
# 5 x 2 = 10
# 6 x 2 = 12
# 7 x 2 = 14
# 8 x 2 = 16
# 9 x 2 = 18
# 10 x 2 = 20

# %% [markdown]
# ### 2.2 Take input from user and print table in that range. Suppose user input 5 and 10. Then print table of 5,6,7,8,9,10
#
# ### And ouput should be as follows
#
# 5 x 1 = 5&emsp;&emsp;&ensp;6 x 1 = 6&emsp;&emsp;&ensp;7 x 1 = 7&emsp;&emsp;&ensp;&nbsp;8 x 1 = 8&emsp;&emsp;&ensp;9 x 1 = 9&emsp;&emsp;&ensp;10 x 1 = 10
# 5 x 2 = 10&emsp;&emsp;6 x 2 = 12&emsp;&emsp;7 x 2 = 14&emsp;&emsp;8 x 2 = 16&emsp;&emsp;9 x 2 = 18&emsp;&emsp;10 x 2 = 20
# 5 x 3 = 15&emsp;&emsp;6 x 3 = 18&emsp;&emsp;7 x 3 = 21&emsp;&emsp;8 x 3 = 24&emsp;&emsp;9 x 3 = 27&emsp;&emsp;10 x 3 = 30
# 5 x 4 = 20&emsp;&emsp;6 x 4 = 24&emsp;&emsp;7 x 4 = 28&emsp;&emsp;8 x 4 = 32&emsp;&emsp;9 x 4 = 36&emsp;&emsp;10 x 4 = 40
# 5 x 5 = 25&emsp;&emsp;6 x 5 = 30&emsp;&emsp;7 x 5 = 35&emsp;&emsp;8 x 5 = 40&emsp;&emsp;9 x 5 = 45&emsp;&emsp;10 x 5 = 50
# 5 x 6 = 30&emsp;&emsp;6 x 6 = 36&emsp;&emsp;7 x 6 = 42&emsp;&emsp;8 x 6 = 48&emsp;&emsp;9 x 6 = 54&emsp;&emsp;10 x 6 = 60
# 5 x 7 = 35&emsp;&emsp;6 x 7 = 42&emsp;&emsp;7 x 7 = 49&emsp;&emsp;8 x 7 = 56&emsp;&emsp;9 x 7 = 63&emsp;&emsp;10 x 7 = 70
# 5 x 8 = 40&emsp;&emsp;6 x 8 = 48&emsp;&emsp;7 x 8 = 56&emsp;&emsp;8 x 8 = 64&emsp;&emsp;9 x 8 = 72&emsp;&emsp;10 x 8 = 80
# 5 x 9 = 45&emsp;&emsp;6 x 9 = 54&emsp;&emsp;7 x 9 = 63&emsp;&emsp;8 x 9 = 72&emsp;&emsp;9 x 9 = 81&emsp;&emsp;10 x 9 = 90
# 5 x 10 = 50&emsp;&ensp;6 x 10 = 60&emsp;&ensp;7 x 10 = 70&emsp;&nbsp;8 x 10 = 80&emsp;&ensp;9 x 10 = 90&emsp;&ensp;10 x 10 = 100
#
# ## Solution

# %%
start = int(input("Please enter start point "))
end = int(input("Please enter end point "))
for tablerange in range(1,11):
    for userrange in range(start,end+1):
        print("{} x {} = {}".format(tablerange, userrange, tablerange*userrange),end="\t")
    print("")
# Out:
# Please enter start point 1
# Please enter end point 2
# 1 x 1 = 1	1 x 2 = 2
# 2 x 1 = 2	2 x 2 = 4
# 3 x 1 = 3	3 x 2 = 6
# 4 x 1 = 4	4 x 2 = 8
# 5 x 1 = 5	5 x 2 = 10
# 6 x 1 = 6	6 x 2 = 12
# 7 x 1 = 7	7 x 2 = 14
# 8 x 1 = 8	8 x 2 = 16
# 9 x 1 = 9	9 x 2 = 18
# 10 x 1 = 10	10 x 2 = 20
